# %% [markdown]
# <a href="https://colab.research.google.com/github/hodades/Mastering-Sentiment-Analysis-with-Transformers-An-In-Depth-Guide/blob/main/Mastering_Sentiment_Analysis_with_Transformers_An_In_Depth_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mastering Sentiment Analysis with Transformers: An In-Depth Guide

# %% [markdown]
# Hello !
# I'm Hoda, currently pursuing a Master of Science in Data & AI Applied for Business and building on my strong mathematical background (licence en mathematiques), I took on this Sentiment Analysis project alongside my studies. I applied my academic knowledge to leverage advanced models and conducted comprehensive exploratory data analysis (EDA), effectively bridging theoretical concepts with practical implementation. This experience has deepened my understanding of AI's real-world applications in business contexts. 😊

# %% [markdown]
# <center><h1><div class="top_section">Table of Contents</div></h1></center>
#
# 1. **[Sentiment Analysis](#sentiment_analysis)**
#
#     - [Types of Sentiment Analysis](#types_of_sentiment_analysis)
#         - [Emotion Detection](#emotion_detection)
#         - [Multilingual Sentiment Analysis](#multilingual_sentiment_analysis)
#         - [Graded Sentiment Analysis](#graded_sentiment_analysis)
#         - [Aspect-Based Sentiment Analysis](#aspect_based_sentiment_analysis)
#         - [Intent Analysis](#intent_analysis)
#
#     - [Importance of Sentiment Analysis](#importance_of_sentiment_analysis)
#
#     - [Key Benefits of Sentiment Analysis](#key_benefits_of_sentiment_analysis)
#         - [Data Sorting at Scale](#data_sorting_at_scale)
#         - [Real-Time Analysis](#real_time_analysis)
#         - [Uncovering Marketing Strategies](#uncovering_marketing_strategies)
#
#     - [Mechanism of Sentiment Analysis](#mechanism_of_sentiment_analysis)
#
#     - [Approaches to Sentiment Analysis](#approaches_to_sentiment_analysis)
#         - [Rule-Based Approaches](#rule_based_approaches)
#         - [Automated Approaches](#automated_approaches)
#
# 2. **[Exploratory Data Analysis (EDA)](#eda)**
#     - [Dataset Information](#dataset_information)
#     - [Problem Overview](#problem_overview)
#     - [Imports](#imports)
#     - [Helper Functions](#helper_functions)
#     - [Data Reading](#data_reading)
#     - [Visualizations](#visualizations)
#         - [Word Cloud](#word_cloud)
#         - [Target Distribution](#target_distribution)
#         - [Token Counts (Simple Tokenizer)](#token_counts_simple_tokenizer)
#         - [Token Counts (BERT Tokenizer)](#token_counts_bert_tokenizer)
#         - [Character Counts in Data](#character_counts_in_data)
#         - [Review Length Analysis](#review_length_analysis)
#         - [Word Count Analysis](#word_count_analysis)
#         - [Most Frequent Words](#most_frequent_words)
#         - [Most Frequent n-grams](#most_frequent_ngrams)
#
# 3. **[Models](#models)**
#     - [Overview of BERT](#overview_of_bert)
#     - [Overview of XLNet](#overview_of_xlnet)
#     - [Overview of RoBERTa](#overview_of_roberta)
#     - [Comparing Transformer Models](#comparing_transformer_models)
#     - [BERT Data Preprocessing](#bert_data_preprocessing)
#     - [Train and Validation Split](#train_and_validation_split)
#     - [Tokenization and Data Encoding with BERT](#tokenization_data_encoding_bert)
#     - [Model Creation](#model_creation)
#     - [Data Loaders Setup](#data_loaders_setup)
#     - [Optimizer and Scheduler](#optimizer_scheduler)
#     - [Performance Metrics](#performance_metrics)
#     - [Training Loop](#training_loop)
#     - [Validation Testing](#validation_testing)
#
# 4. **[Error Analysis](#error_analysis)**
# 5. **[Inference](#inference)**
# 6. **[References](#references)**

# %% [markdown]
# # 1.Sentiment Analysis

# %% [markdown]
# ![1692806351486.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Sentiment analysis (or opinion mining) is a natural language processing (NLP) technique used to determine whether data is positive, negative or neutral. Sentiment analysis is often performed on textual data to help businesses monitor brand and product sentiment in customer feedback, and understand customer needs.
#
# Sentiment analysis helps data analysts within large enterprises gauge public opinion, conduct nuanced market research, monitor brand and product reputation, and understand customer experiences. In addition, companies often develop sentiment analysis systems for customer experience management, social media monitoring, or workforce analytics platform to about their own customers.

# %% [markdown]
# ---

# %% [markdown]
# # Types of sentiment Analysis

# %% [markdown]
# ![Sentiment-graphic-1024x597.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The image explains how sentiment analysis can be applied in different ways:
#
# 1. **Parse Content, Aggregate Sentiment**: Analyze text data to summarize overall sentiment.
# 2. **Monetize as Subscription Market Research**: Use sentiment insights to offer paid market analysis services.
# 3. **Anticipate Next Round of Innovation**: Identify trends and predict future changes or innovations.
# 4. **Do Longitudinal Market Analysis**: Track sentiment changes over time to understand long-term patterns.
# 5. **Find Market Sentiment-Revealing Content**: Discover content that reflects market opinions and preferences.

# %% [markdown]
# ---

# %% [markdown]
# **Emotion Analysis :**

# %% [markdown]
# ![People-emotions-collage-1024x768.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Emotion detection is a type of analysis that identifies specific emotions like happiness, anger, frustration, or sadness in text.
#
# However, this can be challenging because people express emotions in many ways. Sometimes, they may use words that usually have a negative meaning to show a positive feeling. For example, the sentence "I connect to customer service too late, it's killing me" shows frustration (negative). But the sentence "You are killing me" can be used in a positive, playful way. This makes it hard for models to accurately classify emotions.

# %% [markdown]
# **Multilingual Sentiment Analysis**

# %% [markdown]
# Multilingual Sentiment Analysis is the process of analyzing sentiment across different languages. It allows systems to understand and evaluate sentiment in texts written in multiple languages.
#
# There are two main approaches for this:
#
# 1. **Language Detection**: First, identify the language of the text using a language classifier. Then, use a sentiment analysis model specifically trained for that language.
#
# 2. **Multilingual Model**: Develop a single model that supports multiple languages. This model is trained and fine-tuned to work effectively across various languages.

# %% [markdown]
# ---

# %% [markdown]
# **Graded Sentiment Analysis**

# %% [markdown]
# ![istockphoto-1257808721-170667a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# If it's important to be precise about the mood, the categories can be more detailed instead of just "positive" or "negative." For example:
#
# - Very Positive
# - Positive
# - Neutral
# - Negative
# - Very Negative
#
# This type of detailed classification is often used for ratings and reviews, like those that use a 5-star system:
#
# - **Very Positive** = 5 stars
# - **Very Negative** = 1 star

# %% [markdown]
# ---

# %% [markdown]
# **Aspect-based Sentiment Analysis**:
#
# Aspect-based Sentiment Analysis goes beyond just determining if a comment or opinion is positive or negative. It identifies what specific part of the text is being talked about and what sentiment is associated with it.
#
# For example, in the sentence "I did not like the product at all; the size is too small," the overall sentiment is negative. However, aspect-based sentiment analysis also highlights that the complaint is specifically about the size of the product. This provides a more detailed understanding compared to regular sentiment analysis, which would only label the entire sentence as negative.

# %% [markdown]
# ![An-example-of-aspect-based-sentiment-analysis.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **Intent Analysis**

# %% [markdown]
# Intent analysis aims to understand what the user intends to do. By identifying the user’s intention, we can better guide them to achieve their goals.
#
# For example, if a customer on an e-commerce site shows signs of wanting to make a purchase, intent analysis can help recommend relevant products to them.
#
# A common application of intent analysis is in smart assistant systems within apps. It helps direct users to the right features or sections based on their needs, improving their overall experience with the application.

# %% [markdown]
# ## Why Is Sentiment Analysis Important?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# People today frequently share their opinions and emotions on social media, e-commerce platforms, and other online sites, generating a massive amount of data. Brands and companies are increasingly interested in understanding what people are saying about them. They work hard to quickly identify their customers' needs and expectations, allowing them to offer the right services and products. By knowing what makes their customers happy or disappointed, they can adjust their offerings to better meet these needs. Additionally, brands want to measure the impact of their advertisements on users.
#
# For these reasons, sentiment analysis is becoming more important every day.
#
# ### The Benefits of Sentiment Analysis:
#
# 1. **Sorting Data at Scale**
#    With countless comments being made about brands, it's almost impossible to manually process all of them. Sentiment analysis allows businesses to automatically classify and organize large volumes of raw data efficiently.
#
# 2. **Real-Time Analysis**
#    Companies can analyze social media comments in real time to understand customer needs and preferences. This helps them identify dissatisfied customers quickly and take action to improve their satisfaction.
#
# 3. **Discovering New Marketing Strategies**
#    Sentiment analysis provides valuable insights that help organizations develop effective marketing strategies. By measuring customer reactions (positive or negative) to marketing campaigns, companies can refine their strategies. Monitoring customer conversations on social media also helps brands detect key messages, enabling them to create targeted marketing campaigns for specific consumer groups.

# %% [markdown]
# ---

# %% [markdown]
# ### How Does Sentiment Analysis Work?
#
# Sentiment analysis uses natural language processing (NLP), rule-based methods, and machine learning algorithms to automatically determine the emotional tone of a text.
#
# There are various ways to conduct sentiment analysis, depending on factors like the amount of data to be analyzed, the required accuracy, and available resources. Here, we’ll discuss some common methods.
#
# ### Types of Sentiment Analysis Approaches:
#
# 1. **Rule-Based Systems**
#    These systems use a set of manually crafted rules to automatically determine sentiment. They often focus on aspects such as the subjectivity, polarity (positive/negative), or the specific subject of the sentence. A common tool used in these systems is "regex" (regular expressions).
#
#    Rule-based systems typically use two main NLP techniques:
#    - **Stemming, Tokenization, Part-of-Speech Tagging, and Parsing**: These techniques help break down and analyze the text.
#    - **Lexicons**: Lists of words and phrases with assigned polarities (e.g., good-bad, best-worst).
#
#    The mechanism works like this:
#    - A list of polarized words is built (e.g., bad-good, worst-best).
#    - The system then calculates the ratio of positive and negative words in a sentence.
#
#    However, rule-based approaches are becoming less popular because they struggle with nuances like sarcasm and irony, making it difficult to accurately determine the user’s true emotions. As a result, automated approaches are gaining more importance.
#
# 2. **Automatic Approaches**
#    These systems don’t depend on predefined rules; instead, they use machine learning techniques, such as classification, to learn from data. Sentiment analysis models classify text into categories like positive, negative, or neutral.
#
#    Here’s how a machine learning classifier works:
#
#    - **Classification Algorithms**: Sentiment analysis typically uses algorithms such as Naïve Bayes, Logistic Regression, Support Vector Machines (SVM), or Neural Networks:
#      - **Naïve Bayes**: A simple probabilistic classifier based on Bayes' theorem that assumes independence between features.
#      - **Logistic Regression**: A linear approach that models the relationship between a dependent variable (response) and one or more independent variables.
#      - **Support Vector Machines (SVM)**: A supervised learning algorithm used for classification tasks. It finds the best boundary (hyperplane) to separate classes.
#      - **Deep Learning**: Part of a larger family of machine learning methods that rely on neural networks. This approach can be supervised, semi-supervised, or unsupervised.

# %% [markdown]
# #2. EDA

# %% [markdown]
# ### Information about the Data
# Hotels are an essential part of travel experiences, and with easier access to information, travelers now have new ways to choose the best options. This dataset contains 20,000 reviews collected from Tripadvisor, allowing you to analyze what makes a hotel great. You can even use the insights from this model for your own travel planning!
#
# **How to Use the Data:**
# - **Predict Review Rating**: Estimate the rating based on the text of the review.
# - **Topic Modeling on Reviews**: Identify common themes and topics within the reviews.
# - **Explore Key Aspects**: Discover the specific factors that make hotels good or bad.
#
# ### Information about the Problem
# Customer satisfaction is vital in the service industry. It's important to understand the emotions behind customer feedback to improve services. Therefore, we need to classify the sentiment expressed in our hotel reviews dataset to determine the users' emotional states.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from wordcloud import WordCloud
import seaborn as sns
import re
import string
from collections import Counter, defaultdict

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import plot

import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stopWords_nltk = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# This code provides several functions for text preprocessing, specifically for cleaning and tokenizing text data:
#
# 1. **CleanText Class**: This class removes unwanted characters from the text, keeping only specific characters like letters, digits, and punctuation. It can handle both strings and lists of strings.
# 2. **remove_emoji Function**: This function removes emojis and other special symbols from the text using a predefined pattern.
# 3. **tokenize Function**: This function splits the text into basic tokens (words, numbers, and punctuation) and returns a cleaned version of the text.
# 4. **remove_punct Function**: This function removes all punctuation from the text.
#
# The overall goal of the code is to clean, tokenize, and standardize text data for further processing or analysis.

# %%
import re
from typing import Union, List

class CleanText():
    """ clearing text except digits () . , word character """

    def __init__(self, clean_pattern = r"[^A-ZĞÜŞİÖÇIa-zğüı'şöç0-9.\"',()]"):
        self.clean_pattern =clean_pattern

    def __call__(self, text: Union[str, list]) -> List[List[str]]:

        if isinstance(text, str):
            docs = [[text]]

        if isinstance(text, list):
            docs = text

        text = [[re.sub(self.clean_pattern, " ", sent) for sent in sents] for sents in docs]

        return text

def remove_emoji(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642"
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

def tokenize(text):
    """ basic tokenize method with word character, non word character and digits """
    text = re.sub(r" +", " ", str(text))
    text = re.split(r"(\d+|[a-zA-ZğüşıöçĞÜŞİÖÇ]+|\W)", text)
    text = list(filter(lambda x: x != '' and x != ' ', text))
    sent_tokenized = ' '.join(text)
    return sent_tokenized

regex = re.compile('[%s]' % re.escape(string.punctuation))

def remove_punct(text):
    text = regex.sub(" ", text)
    return text

clean = CleanText()

# %%
# label encode
def label_encode(x):
    if x == 1 or x == 2:
        return 0
    if x == 3:
        return 1
    if x == 5 or x == 4:
        return 2

# label to name
def label2name(x):
    if x == 0:
        return "Negative"
    if x == 1:
        return "Neutral"
    if x == 2:
        return "Positive"

# %% [markdown]
# ### Read Data

# %%
df = pd.read_csv('/content/tripadvisor_hotel_reviews (1).csv')

# %%
# show column names
print("df.columns: ", df.columns)
# Out:
# df.columns:  Index(['Review', 'Rating'], dtype='object')

# %%
# head of df
df.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
# count of ratings
fig = px.histogram(df,
             x = 'Rating',
             title = 'Histogram of Review Rating',
             template = 'ggplot2',
             color = 'Rating',
             color_discrete_sequence= px.colors.sequential.Blues_r,
             opacity = 0.8,
             height = 525,
             width = 835,
            )

fig.update_yaxes(title='Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20491 entries, 0 to 20490
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  20491 non-null  object
#  1   Rating  20491 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 320.3+ KB

# %%
# encode label and mapping label name
df["label"] = df["Rating"].apply(lambda x: label_encode(x))
df["label_name"] = df["label"].apply(lambda x: label2name(x))

# %%
# clean text, lowercase and remove punk
df["Review"] = df["Review"].apply(lambda x: remove_punct(clean(remove_emoji(x).lower())[0][0]))

# %%
df.head()
# Out:
#                                               Review  Rating  label label_name
# 0  nice hotel expensive parking got good deal sta...       4      2   Positive
# 1  ok nothing special charge diamond member hilto...       2      0   Negative
# 2  nice rooms not 4  experience hotel monaco seat...       3      1    Neutral
# 3  unique  great stay  wonderful time hotel monac...       5      2   Positive
# 4  great stay great stay  went seahawk game aweso...       5      2   Positive

# %% [markdown]
# # Visualizations
#
# **Word Cloud**
# Word clouds generators work by breaking the text down into component words and counting how frequently they appear in the body of text. We can quickly obtain preliminary information about the data. We can understand what a dataset we don't know is talking about.

# %%
def show_wordcloud(data, title=None):
    # Generate the word cloud
    wordcloud = WordCloud(
        background_color='black',
        max_words=200,
        max_font_size=40,
        scale=3,  # Higher scale for better resolution
        colormap='plasma',  # Changed to 'plasma' for a warm, vibrant color palette
        random_state=42
    ).generate(" ".join(data))

    # Display the word cloud
    plt.figure(figsize=(10, 10))  # Adjusted size for better viewing
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')

    if title:
        plt.title(title, fontsize=18, pad=20)  # Adjusted title padding and size

    plt.show()

# Example usage
show_wordcloud(df["Review"].values)

# %% [markdown]
# # Target Count :
# How many targets do we have? Learning this information will give us an idea about the model we will build. It will also provide guidance on our methods of analyzing data.

# %%
# Create a subplot with one row and two columns
fig = make_subplots(rows=1, cols=2, specs=[[{"type": "pie"}, {"type": "bar"}]])

# Define a new color palette for better contrast and vibrancy
colors = ['#FFA07A', '#20B2AA', '#FFD700', '#8A2BE2', '#FF6347']

# Add a pie chart to the first column
fig.add_trace(go.Pie(
    labels=df.label_name.value_counts().index,
    values=df.label.value_counts().values,
    hole=0.3,  # Added a hole for a donut-style pie chart
    marker=dict(colors=colors, line=dict(color='#FFFFFF', width=2))  # White border for better separation
), 1, 1)

# Update the pie chart traces for better visuals
fig.update_traces(hoverinfo='label+percent', textfont_size=18)

# Add a bar chart to the second column
fig.add_trace(go.Bar(
    x=df.label_name.value_counts().index,
    y=df.label.value_counts().values,
    marker_color=colors[:len(df.label_name.value_counts())],  # Apply the same colors to bars
    text=df.label.value_counts().values,  # Display values on the bars
    textposition='auto'  # Automatic positioning of text on bars
), 1, 2)

# Update layout for improved aesthetics
fig.update_layout(
    title_text="Distribution of Labels - Pie and Bar Chart",
    title_x=0.5,
    showlegend=False,
    template="plotly_white",  # Apply a clean and modern template
    font=dict(size=16),
    height=500,
    width=1000,
    margin=dict(l=40, r=40, t=40, b=40)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Token Counts with simple tokenizer :
# Finding out the number of tokens available for each sample will give us information about the length of our data. The classification algorithm we will use for a long text will not be the same as the algorithm used for a short text.

# %%
# tokenize data
df["tokenized_review"] = df.Review.apply(lambda x: tokenize(x))
# calculate token count for any sent
df["sent_token_length"] = df["tokenized_review"].apply(lambda x: len(x.split()))

# %%
fig = px.histogram(df, x="sent_token_length", nbins=20, color_discrete_sequence=px.colors.cmocean.algae, barmode='group', histnorm="percent")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
(df.sent_token_length < 512).mean()
# Out:
# 0.989117173393197

# %% [markdown]
# **Token Counts with BERT tokenizer :**
#
# Since we will create a Transformers-based model, the value that BERT tokinezer will give us is very important. With the information here, the value of the seq_len parameter that we will use while encoding the data will be decided.

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',
                                          do_lower_case=True)

# %%
# data tokenize with bert tokenizer
df["sent_bert_token_length"] = df["Review"].apply(lambda x: len(tokenizer(x, add_special_tokens=False)["input_ids"]))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (658 > 512). Running this sequence through the model will result in indexing errors

# %%
fig = px.histogram(df, x="sent_token_length", nbins=20, color_discrete_sequence=px.colors.cmocean.algae, barmode='group', histnorm="percent")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Less than 512 covers how many of the data
(df.sent_bert_token_length < 512).mean()
# Out:
# 0.9853106241764678

# %% [markdown]
# # Characters Count in the Data :
# Let's look at the frequency of the number of characters. It will give us information about the overall size of our data

# %%
# valvulate char count for each review
df['char_count'] = df['Review'].apply(lambda x: len(str(x)))


def plot_dist3(df, feature, title):
    fig = plt.figure(constrained_layout=True, figsize=(18, 8))
    grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)
    ax1 = fig.add_subplot(grid[0, :2])
    ax1.set_title('Histogram')
    sns.distplot(df.loc[:, feature],
                 hist=True,
                 kde=True,
                 ax=ax1,
                 )
    ax1.set(ylabel='Frequency')
    ax1.xaxis.set_major_locator(MaxNLocator(nbins=20))


    plt.suptitle(f'{title}', fontsize=24)

# %%
plot_dist3(df, 'char_count',
           'Characters Count in Data')

# %% [markdown]
# # Reviews Lengths:
# Looking at the number of characters in each review can tell us interesting things about the data. Here, we see that negative reviews are shorter compared to neutral and positive ones. This suggests that people often keep their negative thoughts brief ;)

# %%
# Creating a new feature for the visualization.
df['Character Count'] = df['Review'].apply(lambda x: len(str(x)))


def plot_dist3(df, feature, title):
    # Creating a customized chart. and giving in figsize and everything.
    fig = plt.figure(constrained_layout=True, figsize=(24, 12))
    # Creating a grid of 3 cols and 3 rows.
    grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)

    # Customizing the histogram grid.
    ax1 = fig.add_subplot(grid[0, :2])
    # Set the title.
    ax1.set_title('Histogram')
    # plot the histogram.
    sns.distplot(df.loc[:, feature],
                 hist=True,
                 kde=True,
                 ax=ax1,
                 color='#e74c3c')
    ax1.set(ylabel='Frequency')
    ax1.xaxis.set_major_locator(MaxNLocator(nbins=20))

    # Customizing the ecdf_plot.
    ax2 = fig.add_subplot(grid[1, :2])
    # Set the title.
    ax2.set_title('Empirical CDF')
    # Plotting the ecdf_Plot.
    sns.distplot(df.loc[:, feature],
                 ax=ax2,
                 kde_kws={'cumulative': True},
                 hist_kws={'cumulative': True},
                 color='#e74c3c')
    ax2.xaxis.set_major_locator(MaxNLocator(nbins=20))
    ax2.set(ylabel='Cumulative Probability')

    plt.suptitle(f'{title}', fontsize=24)

# %%
plot_dist3(df[df['label'] == 0], 'Character Count',
           'Characters Count "Negative" Rewiev')

# %%
plot_dist3(df[df['label'] == 2], 'Character Count',
           'Characters Per "Positive" Rewiev')

# %%
plot_dist3(df[df['label'] == 1], 'Character Count',
           'Characters Per "Neutral" Rewiev')

# %% [markdown]
# #Word Counts
# We see that the situation in the number of characters and the situation in the number of words are the same. We have seen that people use less word count when expressing negative things.

# %%
def plot_word_number_histogram(textno, textye, textz):

    """A function for comparing word counts"""

    fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(18, 12), sharey=True)
    sns.distplot(textno.str.split().map(lambda x: len(x)), ax=axes[0], color='#e74c3c')
    sns.distplot(textye.str.split().map(lambda x: len(x)), ax=axes[1], color='#e74c3c')
    sns.distplot(textz.str.split().map(lambda x: len(x)), ax=axes[2], color='#e74c3c')


    axes[0].set_xlabel('Word Count')
    axes[0].set_ylabel('Frequency')
    axes[0].set_title('negative')
    axes[1].set_xlabel('Word Count')
    axes[1].set_title('netrual')
    axes[2].set_xlabel('Word Count')
    axes[2].set_title('positive')

    fig.suptitle('Words Per Review', fontsize=24, va='baseline')

    fig.tight_layout()

# %%
plot_word_number_histogram(df[df['label'] == 0]['Review'],
                           df[df['label'] == 1]['Review'],
                           df[df['label'] == 2]['Review'],
                          )

# %%
# remove punk
df['tokenized_review'] = df['tokenized_review'].apply(lambda x: remove_punct(x))

# %% [markdown]
# #Most Common Words

# %%
texts = df['tokenized_review']
new = texts.str.split().explode()  # More efficient with explode
corpus = new[~new.isin(stopWords_nltk)]  # Filter stopwords directly
counter = Counter(corpus)
most = counter.most_common(30)

x, y = zip(*most)  # Unpack directly

fig = go.Figure(go.Bar(
    x=y,
    y=x,
    orientation='h',
    marker=dict(
        color='rgba(34, 139, 230, 0.6)',
        line=dict(color='rgba(34, 139, 230, 1.0)', width=1)
    ),
    name='Most Common Words',
))

fig.update_layout(
    title=dict(text="Most Common Words", y=0.9, x=0.5, xanchor='center', yanchor='top'),
    font=dict(family="Arial, sans-serif", size=16, color="Black"),
    margin=dict(l=50, r=50, t=70, b=50),
    height=600,
    template='simple_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Most Common ngrams

# %%
fig = make_subplots(rows=1, cols=3)
title_ = ["negative", "neutral", "positive"]

for i in range(3):
    texts = df[df["label"] == i]['tokenized_review']

    new = texts.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]
    counter = Counter(corpus)
    most = counter.most_common()
    x, y = [], []

    for word, count in most[:30]:
        if word not in stopWords_nltk:
            x.append(word)
            y.append(count)

    fig.add_trace(go.Bar(
                x=y,
                y=x,
                orientation='h', type="bar",
        name=title_[i], marker=dict(color=colors[i])), 1, i+1)

fig.update_layout(
    autosize=False,
    width=2000,
    height=600,title=dict(
        text='<b>Most Common ngrams per Classes</b>',
        x=0.5,
        y=0.95,
        font=dict(
        family="Courier New, monospace",
        size=24,
        color="RebeccaPurple"
        )
    ),)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def _get_top_ngram(corpus, n=None):
    #getting top ngrams
    vec = CountVectorizer(ngram_range=(n, n),
                          max_df=0.9,
                          ).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    return words_freq[:15]

# %%
# unigram
fig = make_subplots(rows=1, cols=3)

title_ = ["negative", "neutral", "positive"]

for i in range(3):
    texts = df[df["label"] == i]['tokenized_review']

    new = texts.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]
    top_n_bigrams = _get_top_ngram(texts, 2)[:15]
    x, y = map(list, zip(*top_n_bigrams))


    fig.add_trace(go.Bar(
                x=y,
                y=x,
                orientation='h', type="bar",
        name=title_[i], marker=dict(color=colors[i])), 1, i+1)


fig.update_layout(
    autosize=False,
    width=2000,
    height=600,title=dict(
        text='<b>Most Common unigrams per Classes</b>',
        x=0.5,
        y=0.95,
        font=dict(
        family="Courier New, monospace",
        size=24,
        color="RebeccaPurple"
        )
    ))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#trigram

fig = make_subplots(rows=1, cols=3)
title_ = ["negative", "neutral", "positive"]

for i in range(3):
    texts = df[df["label"] == i]['tokenized_review']

    new = texts.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]

    top_n_bigrams = _get_top_ngram(texts, 3)[:15]
    x, y = map(list, zip(*top_n_bigrams))

    fig.add_trace(go.Bar(
                x=y,
                y=x,
                orientation='h', type="bar",
        name=title_[i], marker=dict(color=colors[i])), 1, i+1),

fig.update_layout(
    autosize=False,
    width=2000,
    height=600,title=dict(
        text='<b>Most Common trigrams per Classes</b>',
        x=0.5,
        y=0.95,
        font=dict(
        family="Courier New, monospace",
        size=24,
        color="RebeccaPurple"
        )
    ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We examined and visualized the data, now we can move on to the model building part.
